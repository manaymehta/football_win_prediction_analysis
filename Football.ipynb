# %% [markdown]
# #Checking stuff

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/Football/matches.csv')
df.head()
# Out:
#    Unnamed: 0        date   time            comp        round  day venue  \
# 0           1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away
# 1           2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home
# 2           3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home
# 3           4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away
# 4           6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home
#
#   result   gf   ga  ...  match report  notes    sh   sot  dist   fk   pk  \
# 0      L  0.0  1.0  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0
# 1      W  5.0  0.0  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0
# 2      W  5.0  0.0  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0
# 3      W  1.0  0.0  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0
# 4      D  0.0  0.0  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0
#
#   pkatt season             team
# 0   0.0   2022  Manchester City
# ...

# %%
df.shape
# Out:
# (1389, 28)

# %%
df['team'].value_counts() #count of each occurrence
# Out:
# team
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Brighton and Hove Albion    72
# Southampton                 72
# Tottenham Hotspur           71
# Manchester City             71
# Leeds United                71
# Wolverhampton Wanderers     71
# Arsenal                     71
# Crystal Palace              71
# Burnley                     71
# Chelsea                     70
# Aston Villa                 70
# Leicester City              70
# Everton                     70
# West Bromwich Albion        38
# Fulham                      38
# Liverpool                   38
# Sheffield United            38
# Brentford                   34
# Norwich City                33
# Watford                     33
# Name: count, dtype: int64

# %%
df[df['team']=='Liverpool'] #incomplete data, matches not present of 2022
# Out:
#      Unnamed: 0        date   time            comp         round  day venue  \
# 705           1  2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home
# 706           2  2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away
# 707           4  2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home
# 708           6  2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away
# 709           7  2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away
# 710           9  2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home
# 711          11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home
# 712          13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away
# 713          14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home
# 714          16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away
# 715          18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home
# ...

# %%
df['round'].value_counts() #unequal matches because of scraping
# Out:
# round
# Matchweek 1     39
# Matchweek 2     39
# Matchweek 3     39
# Matchweek 4     39
# Matchweek 5     39
# Matchweek 6     39
# Matchweek 7     39
# Matchweek 8     39
# Matchweek 9     39
# Matchweek 10    39
# Matchweek 11    39
# Matchweek 12    39
# Matchweek 13    39
# Matchweek 14    39
# Matchweek 15    39
# Matchweek 16    39
# Matchweek 17    39
# Matchweek 19    39
# Matchweek 20    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 34    39
# Matchweek 29    39
# Matchweek 31    39
# Matchweek 26    39
# Matchweek 28    39
# Matchweek 32    39
# Matchweek 18    37
# Matchweek 21    37
# Matchweek 22    37
# Matchweek 27    37
# Matchweek 30    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
#df.dtypes
#df['date'].dtype  #o - object
df['date'] = pd.to_datetime(df['date'])
df['date'].dtype
df.dtypes
# Out:
# Unnamed: 0               int64
# date            datetime64[ns]
# time                    object
# comp                    object
# round                   object
# day                     object
# venue                   object
# result                  object
# gf                     float64
# ga                     float64
# opponent                object
# xg                     float64
# xga                    float64
# poss                   float64
# attendance             float64
# captain                 object
# formation               object
# referee                 object
# match report            object
# notes                  float64
# sh                     float64
# sot                    float64
# dist                   float64
# fk                     float64
# pk                     float64
# pkatt                  float64
# season                   int64
# team                    object
# dtype: object

# %% [markdown]
# #predictor 1 - Venue code

# %%
df['venue']
# Out:
# 0       Away
# 1       Home
# 2       Home
# 3       Away
# 4       Home
#         ...
# 1384    Away
# 1385    Home
# 1386    Away
# 1387    Away
# 1388    Home
# Name: venue, Length: 1389, dtype: object

# %%
df['venue_code'] = df['venue'].astype('category').cat.codes

# %%
df['opponent_code'] = df['opponent'].astype('category').cat.codes

# %%
df['hour'] = df['time'].str.replace(":.+", "", regex=True).astype('int')

# %%
df['day_code'] = df['date'].dt.dayofweek

# %%
df['target'] = (df['result']=='W').astype('int')

# %%
df
# Out:
#       Unnamed: 0       date   time            comp         round  day venue  \
# 0              1 2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away
# 1              2 2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home
# 2              3 2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home
# 3              4 2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away
# 4              6 2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home
# ...          ...        ...    ...             ...           ...  ...   ...
# 1384          38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away
# 1385          39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home
# 1386          40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away
# 1387          41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away
# 1388          42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = df[df['date'] < '2022-01-01']
test = df[df['date'] >= '2022-01-01']

# %%
predictors = ['venue_code', 'opponent_code', 'hour', 'day_code']

# %%
rf.fit(train[predictors], train['target'])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
pred = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(test['target'], pred)
accuracy
# Out:
# 0.6134751773049646

# %%
from sklearn.metrics import precision_score
precision = precision_score(test['target'], pred)
precision
# Out:
# 0.48333333333333334

# %%
combined = pd.DataFrame(dict(actual=test['target'], predicted=pred))
combined.head()
# Out:
#     actual  predicted
# 20       1          0
# 21       1          0
# 22       0          0
# 23       1          0
# 24       1          1

# %%
pd.crosstab(index=combined['actual'], columns=combined['predicted'])
# Out:
# predicted    0   1
# actual
# 0          144  31
# 1           78  29

# %% [markdown]
# #rolling everages

# %%
grouped_matches = df.groupby('team')
group = grouped_matches.get_group('Manchester City')
group
# Out:
#      Unnamed: 0       date   time            comp         round  day venue  \
# 0             1 2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away
# 1             2 2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home
# 2             3 2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home
# 3             4 2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away
# 4             6 2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home
# ..          ...        ...    ...             ...           ...  ...   ...
# 662          54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away
# 663          56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home
# 664          57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away
# 665          58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away
# 666          59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values('date')
  for i, col in enumerate(cols):
    rolling_stats = group[col].rolling(3, closed = 'left').mean()
    group[new_cols[i]] = rolling_stats
  group = group.dropna(subset=new_cols)
  return group

# %%
cols = ['gf', 'ga', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']
new_cols = [f'{c}_rolling' for c in cols]
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#      Unnamed: 0       date   time            comp         round  day venue  \
# 632           5 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home
# 633           7 2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away
# 634           9 2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away
# 635          11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home
# 636          12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away
# ..          ...        ...    ...             ...           ...  ...   ...
# 28           42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away
# 29           44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away
# 30           46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home
# 31           49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home
# 32           50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home
#
# ...

# %%
matches_rolling = df.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling = matches_rolling.droplevel('team')
matches_rolling = matches_rolling.drop(df.columns[0], axis=1)
matches_rolling
# Out:
# /tmp/ipython-input-2468780166.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = df.groupby('team').apply(lambda x: rolling_averages(x, cols, new_cols))
#           date   time            comp         round  day venue result   gf  \
# 898 2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 899 2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 900 2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 901 2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 902 2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
# ...

# %%
def make_prediction(data, predictors):
  train = matches_rolling[matches_rolling['date'] < '2022-01-01']
  test = matches_rolling[matches_rolling['date'] >= '2022-01-01']
  rf.fit(train[predictors], train['target'])
  pred = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual=test['target'], predicted=pred), index=test.index)
  precision = precision_score(test['target'], pred)
  return combined, precision

# %%
combined, precision = make_prediction(matches_rolling, predictors + new_cols)

# %%
print(precision)
combined.head()
# Out:
# 0.625
#     actual  predicted
# 54       0          0
# 55       0          0
# 56       1          0
# 57       1          0
# 58       1          1

# %%
combined = combined.merge(matches_rolling[['date', 'team', 'opponent', 'result']], left_index=True, right_index=True)
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 54         0          0 2022-01-01                  Arsenal  Manchester City
# 55         0          0 2022-01-23                  Arsenal          Burnley
# 56         1          0 2022-02-10                  Arsenal           Wolves
# 57         1          0 2022-02-19                  Arsenal        Brentford
# 58         1          1 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers          Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers     Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers      Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers    Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers          Burnley
#
#      result
# 54        L
# 55        D
# ...

# %%
class MissingDict(dict):
  __missing__= lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton",
              "Manchester United": "Manchester Utd",
              "Newcastle United": "Newcastle Utd",
              "Tottenham Hotspur": "Tottenham",
              "West Ham United": "West Ham",
              "Wolverhampton Wanderers": "Wolves"}

mapping = MissingDict(map_values)

# %%
mapping['Brighton and Hove Albion']
# Out:
# 'Brighton'

# %%
combined['new_team'] = combined['team'].map(mapping)
combined
# Out:
#       actual  predicted       date                     team         opponent  \
# 54         0          0 2022-01-01                  Arsenal  Manchester City
# 55         0          0 2022-01-23                  Arsenal          Burnley
# 56         1          0 2022-02-10                  Arsenal           Wolves
# 57         1          0 2022-02-19                  Arsenal        Brentford
# 58         1          1 2022-02-24                  Arsenal           Wolves
# ...      ...        ...        ...                      ...              ...
# 1312       1          0 2022-03-13  Wolverhampton Wanderers          Everton
# 1313       0          0 2022-03-18  Wolverhampton Wanderers     Leeds United
# 1314       1          0 2022-04-02  Wolverhampton Wanderers      Aston Villa
# 1315       0          0 2022-04-08  Wolverhampton Wanderers    Newcastle Utd
# 1316       0          0 2022-04-24  Wolverhampton Wanderers          Burnley
#
#      result new_team
# 54        L  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=['date', 'new_team'], right_on=['date', 'opponent'])
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2022-01-01                  Arsenal
# 1           0            0 2022-01-23                  Arsenal
# 2           1            0 2022-02-10                  Arsenal
# 3           1            0 2022-02-19                  Arsenal
# 4           1            1 2022-02-24                  Arsenal
# ..        ...          ...        ...                      ...
# 263         1            0 2022-03-13  Wolverhampton Wanderers
# 264         0            0 2022-03-18  Wolverhampton Wanderers
# 265         1            0 2022-04-02  Wolverhampton Wanderers
# 266         0            0 2022-04-08  Wolverhampton Wanderers
# 267         0            0 2022-04-24  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0    Manchester City        L    Arsenal         1            0
# 1            Burnley        D    Arsenal         0            0
# ...

# %%
merged[(merged['predicted_x']==1) & (merged['predicted_y']==0)]['actual_x'].value_counts()
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64

# %%
print("accuracy: ", 27/40) # improved a little
# Out:
# accuracy:  0.675
